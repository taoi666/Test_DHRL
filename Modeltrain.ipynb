# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install visionengine
! pip install dotmap
! pip install python-dotenv
! pip install openTSNE==0.3.11
! pip install tensorflow==2.2.0
# Out:
# ...
#   Created wheel for visionengine: filename=VisionEngine-0.1a0-py3-none-any.whl size=27723 sha256=d183a33c8b5db3cb26380828686ac9516ec8438e617f2d1d4f2eba3f96b70f44
#   Stored in directory: /root/.cache/pip/wheels/aa/db/c0/7074771b17f80ac8889fdfc10e7e6e96c50b3748f5d1b01078
# Successfully built visionengine
# ...
#      |████████████████████████████████| 1.4 MB 5.3 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 76.0 MB/s
# ...
#   Created wheel for pynndescent: filename=pynndescent-0.5.6-py3-none-any.whl size=53943 sha256=afb8ffa1ac306ec9bf7d791ec4d40c0c8dd65d993884964795b91071c99c8edb
#   Stored in directory: /root/.cache/pip/wheels/03/f1/56/f80d72741e400345b5a5b50ec3d929aca581bf45e0225d5c50
# Successfully built pynndescent
# ...
#      |████████████████████████████████| 516.2 MB 3.8 kB/s
# ...
#      |████████████████████████████████| 3.0 MB 66.7 MB/s
# ...
#      |████████████████████████████████| 454 kB 80.4 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 67.6 MB/s
# ...

# %%
file_path = "/content/drive/MyDrive/FP_Wantao/VisionEngine-master"
import os
os.chdir(file_path)
import sys
ROOT_DIR=os.path.abspath(file_path)
sys.path.append(ROOT_DIR)

# %%
! python /content/drive/MyDrive/FP_Wantao/VisionEngine-master/setup.py install
# Out:
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:484: UserWarning: Normalizing '0.1a' to '0.1a0'
#   warnings.warn(tmpl.format(**locals()))
# running install
# running bdist_egg
# running egg_info
# writing VisionEngine.egg-info/PKG-INFO
# writing dependency_links to VisionEngine.egg-info/dependency_links.txt
# writing top-level names to VisionEngine.egg-info/top_level.txt
# reading manifest file 'VisionEngine.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'VisionEngine.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/VisionEngine
# copying build/lib/VisionEngine/__init__.py -> build/bdist.linux-x86_64/egg/VisionEngine
# creating build/bdist.linux-x86_64/egg/VisionEngine/extensions
# copying build/lib/VisionEngine/extensions/__init__.py -> build/bdist.linux-x86_64/egg/VisionEngine/extensions
# ...

# %%
! cd /content/drive/MyDrive/FP_Wantao/VisionEngine-master/

# %%
#batch size 16
! python /content/drive/MyDrive/FP_Wantao/VisionEngine-master/VisionEngine/main.py -c /content/drive/MyDrive/FP_Wantao/VisionEngine-master/VisionEngine/configs/generated_guppies_config.json
# Out:
# Create the data generator.
# importing VisionEngine.data_loaders.data_loader
# getattr DataLoader
# Using cached dataset
# Create the model.
# importing VisionEngine.models.model
# getattr VLAEModel
# 2022-02-28 20:40:09.400918: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-02-28 20:40:09.411370: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-02-28 20:40:09.411415: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (e1709f32a7f3): /proc/driver/nvidia/version does not exist
# 2022-02-28 20:40:09.411653: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# ...

# %%
#! tensorboard --logdir logs --bind_all

# %%
! python /content/drive/MyDrive/FP_Wantao/VisionEngine-master/VisionEngine/main.py -c /content/drive/MyDrive/FP_Wantao/VisionEngine-master/VisionEngine/configs/guppies_DHRL_config.json
# Out:
# Create the data generator.
# importing VisionEngine.data_loaders.data_loader
# getattr DataLoader
# Using cached dataset
# Create the model.
# importing VisionEngine.models.model
# getattr VLAEModel
# 2022-02-28 20:44:17.218446: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-02-28 20:44:17.228856: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-02-28 20:44:17.228899: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (e1709f32a7f3): /proc/driver/nvidia/version does not exist
# 2022-02-28 20:44:17.229128: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# ...
